# %% [markdown]
# <a href="https://colab.research.google.com/github/Greeshma-babu/AI_Projects/blob/main/Object_Detection_from_Video_using_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics opencv-python numpy matplotlib

# %% [markdown]
# **Load the YOLO Model**

# %%
model = YOLO("yolov8n.pt")
# pt -> Pytorch model file

# %% [markdown]
# **Upload the video**

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-bc7bfab0-712d-4d43-add8-040cef4e7566" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc7bfab0-712d-4d43-add8-040cef4e7566">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Check the uploaded the video**

# %%
video_path = "/content/traffic1.mp4"

# %%
import os
os.listdir("/content")
# Out:
# ['.config', 'yolov8n.pt', 'Traffic1.mp4', 'sample_data']

# %%
# !pip install opencv-python-headless --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 MB 16.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
# ...

# %%
import cv2
from ultralytics import YOLO
from google.colab.patches import cv2_imshow

# Load YOLO Model
model = YOLO("yolov8n.pt")

video_path = "/content/Traffic1.mp4"

cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("❌ Video not found")
    exit()

width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

print("Video Size:", width, height)
print("FPS:", fps)


out = cv2.VideoWriter(
    "/content/traffic_output.mp4",
    cv2.VideoWriter_fourcc(*'mp4v'),
    fps,
    (width, height)
)


frame_count = 0

while cap.isOpened():

    ret, frame = cap.read()

    if not ret:
        break

    # YOLO Detection
    results = model(frame, conf=0.3)

    # Draw bounding boxes
    annotated_frame = results[0].plot()

    # Save output video
    out.write(annotated_frame)

    frame_count += 1

    # Display every 30th frame only
    if frame_count % 100 == 0:
        cv2_imshow(annotated_frame)
        print("Processed frame:", frame_count)


cap.release()
out.release()

print("✅ Processing Completed")
# Out:
# Video Size: 768 432
# FPS: 29.97002997002997
#
# 0: 384x640 3 persons, 13 cars, 3 motorcycles, 1 bus, 1 truck, 167.9ms
# Speed: 3.6ms preprocess, 167.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 14 cars, 3 motorcycles, 1 bus, 153.9ms
# Speed: 7.3ms preprocess, 153.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 13 cars, 3 motorcycles, 1 bus, 1 truck, 157.6ms
# Speed: 6.1ms preprocess, 157.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 11 cars, 2 motorcycles, 1 bus, 2 trucks, 169.9ms
# Speed: 6.4ms preprocess, 169.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 12 cars, 1 motorcycle, 1 bus, 2 trucks, 147.7ms
# Speed: 5.9ms preprocess, 147.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 motorcycle, 1 bus, 161.2ms
# ...
